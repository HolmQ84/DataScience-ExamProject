# %% [markdown]
# ## Preperation for data science examn project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
import sklearn.metrics as sm

# %%
data = pd.read_csv('../../data/charts.csv')

# %%
data.shape
# Out:
# (26173514, 9)

# %%
data.head()
# Out:
#                          title  rank        date  \
# 0      Chantaje (feat. Maluma)     1  2017-01-01
# 1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                       Safari     4  2017-01-01
# 4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  Argentina  top200
#
#            trend   streams
# 0  SAME_POSITION  253019.0
# 1        MOVE_UP  223988.0
# 2      MOVE_DOWN  210943.0
# 3  SAME_POSITION  173865.0
# 4        MOVE_UP  153956.0

# %%
data.tail()
# Out:
#                                   title  rank        date  \
# 26173509                            BYE    46  2021-07-31
# 26173510                        Pillars    47  2021-07-31
# 26173511                   Gái Độc Thân    48  2021-07-31
# 26173512  Renegade (feat. Taylor Swift)    49  2021-07-31
# 26173513                Letter to Jarad    50  2021-07-31
#
#                              artist  \
# 26173509                      Jaden
# 26173510                     My Anh
# 26173511                      Tlinh
# 26173512            Big Red Machine
# 26173513  LRN Slime, Shiloh Dynasty
#
#                                                         url   region    chart  \
# 26173509  https://open.spotify.com/track/3OUyyDN7EZrL7i0...  Vietnam  viral50
# 26173510  https://open.spotify.com/track/6eky30oFiQbHUAT...  Vietnam  viral50
# 26173511  https://open.spotify.com/track/2klsSb2iTfgDh95...  Vietnam  viral50
# 26173512  https://open.spotify.com/track/1aU1wpYBSpP0M6I...  Vietnam  viral50
# 26173513  https://open.spotify.com/track/508QhA2SncMbh5C...  Vietnam  viral50
#
#               trend  streams
# 26173509    MOVE_UP      NaN
# 26173510  NEW_ENTRY      NaN
# 26173511  MOVE_DOWN      NaN
# 26173512  MOVE_DOWN      NaN
# 26173513  MOVE_DOWN      NaN

# %%
data.columns
# Out:
# Index(['title', 'rank', 'date', 'artist', 'url', 'region', 'chart', 'trend',
#        'streams'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# title           11
# rank             0
# date             0
# artist          18
# url              0
# region           0
# chart            0
# trend            0
# streams    5851610
# dtype: int64

# %%
grouped = data.groupby(data["chart"])

# %%
viral_50 = grouped.get_group('viral50')
top200 = grouped.get_group("top200")

# %%
top200.shape
# Out:
# (20321904, 9)

# %%
top200.head()
# Out:
#                          title  rank        date  \
# 0      Chantaje (feat. Maluma)     1  2017-01-01
# 1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                       Safari     4  2017-01-01
# 4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  Argentina  top200
#
#            trend   streams
# 0  SAME_POSITION  253019.0
# 1        MOVE_UP  223988.0
# 2      MOVE_DOWN  210943.0
# 3  SAME_POSITION  173865.0
# 4        MOVE_UP  153956.0

# %%
top200.tail()
# Out:
#                             title  rank        date  \
# 25276069     Ojalá (feat. Darell)   196  2018-01-31
# 25276070  Lo Que Pasa en la Noche   197  2018-01-31
# 25276071            El Equivocado   198  2018-01-31
# 25276072        Que Fui Tu Amante   199  2018-01-31
# 25276073                     Solo   200  2018-01-31
#
#                                         artist  \
# 25276069  De La Ghetto, Almighty, Bryant Myers
# 25276070                           Mano Arriba
# 25276071                           Mano Arriba
# 25276072                   El Gucci y Su Banda
# 25276073                   Amenazzy, Lary Over
#
#                                                         url   region   chart  \
# 25276069  https://open.spotify.com/track/3EMDvnVpQd9RZJv...  Uruguay  top200
# 25276070  https://open.spotify.com/track/2eOleVJlGvBE027...  Uruguay  top200
# 25276071  https://open.spotify.com/track/5vy1C7DD9xJ5fRB...  Uruguay  top200
# 25276072  https://open.spotify.com/track/1fmiCxwEbZFIszI...  Uruguay  top200
# 25276073  https://open.spotify.com/track/2rrJfOphzn4uQCK...  Uruguay  top200
#
#               trend  streams
# 25276069  MOVE_DOWN   1178.0
# 25276070  NEW_ENTRY   1178.0
# 25276071  MOVE_DOWN   1170.0
# 25276072  MOVE_DOWN   1165.0
# 25276073  NEW_ENTRY   1162.0

# %%
viral_50.shape
# Out:
# (5851610, 9)

# %%
viral_50.head()
# Out:
#            title  rank        date      artist  \
# 12808       Boys    13  2017-08-01  Charli XCX
# 12965    Hold Me    19  2017-08-01       R3HAB
# 13781  Hola Hola    40  2017-08-01        KARD
# 14042    Cuídate     4  2017-08-01     Zetazen
# 14092       Boys    13  2017-08-01  Charli XCX
#
#                                                      url      region    chart  \
# 12808  https://open.spotify.com/track/5o4yGlG0PfeVUa6...      Latvia  viral50
# 12965  https://open.spotify.com/track/2a9xGmpgNyNz9QV...  Luxembourg  viral50
# 13781  https://open.spotify.com/track/3VC1IEz9M1txlMS...        Peru  viral50
# 14042  https://open.spotify.com/track/0WgnbqlHieZmdYa...       Spain  viral50
# 14092  https://open.spotify.com/track/5o4yGlG0PfeVUa6...      Taiwan  viral50
#
#                trend  streams
# 12808        MOVE_UP      NaN
# 12965      MOVE_DOWN      NaN
# 13781      NEW_ENTRY      NaN
# 14042  SAME_POSITION      NaN
# 14092      MOVE_DOWN      NaN

# %%
viral_50.tail()
# Out:
#                                   title  rank        date  \
# 26173509                            BYE    46  2021-07-31
# 26173510                        Pillars    47  2021-07-31
# 26173511                   Gái Độc Thân    48  2021-07-31
# 26173512  Renegade (feat. Taylor Swift)    49  2021-07-31
# 26173513                Letter to Jarad    50  2021-07-31
#
#                              artist  \
# 26173509                      Jaden
# 26173510                     My Anh
# 26173511                      Tlinh
# 26173512            Big Red Machine
# 26173513  LRN Slime, Shiloh Dynasty
#
#                                                         url   region    chart  \
# 26173509  https://open.spotify.com/track/3OUyyDN7EZrL7i0...  Vietnam  viral50
# 26173510  https://open.spotify.com/track/6eky30oFiQbHUAT...  Vietnam  viral50
# 26173511  https://open.spotify.com/track/2klsSb2iTfgDh95...  Vietnam  viral50
# 26173512  https://open.spotify.com/track/1aU1wpYBSpP0M6I...  Vietnam  viral50
# 26173513  https://open.spotify.com/track/508QhA2SncMbh5C...  Vietnam  viral50
#
#               trend  streams
# 26173509    MOVE_UP      NaN
# 26173510  NEW_ENTRY      NaN
# 26173511  MOVE_DOWN      NaN
# 26173512  MOVE_DOWN      NaN
# 26173513  MOVE_DOWN      NaN

# %%
top200.region
# Out:
# 0           Argentina
# 1           Argentina
# 2           Argentina
# 3           Argentina
# 4           Argentina
#               ...
# 25276069      Uruguay
# 25276070      Uruguay
# 25276071      Uruguay
# 25276072      Uruguay
# 25276073      Uruguay
# Name: region, Length: 20321904, dtype: object

# %% [markdown]
# ***
# # Martins databehandling

# %%
# Set the amount of rows in sub set.
reduced_data = data.iloc[0:1000]

# %%
# Check the shape of the dataset.
reduced_data.shape
# Out:
# (1000, 9)

# %%
# Find link for accessing data for each song.
reduced_data['url'][0]
# Out:
# 'https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg'

# %%
reduced_data.head()
# Out:
#                          title  rank        date  \
# 0      Chantaje (feat. Maluma)     1  2017-01-01
# 1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                       Safari     4  2017-01-01
# 4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  Argentina  top200
#
#            trend   streams
# 0  SAME_POSITION  253019.0
# 1        MOVE_UP  223988.0
# 2      MOVE_DOWN  210943.0
# 3  SAME_POSITION  173865.0
# 4        MOVE_UP  153956.0

# %% [markdown]
# ### Import SpotiPY and insert ID and Secret to access audio features from spotify.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Authentication spotify - without user
client_credentials_manager = SpotifyClientCredentials(client_id="3a2f65eb20164b24b59b7fdd6876bb51", client_secret="9f6d3a070cdf4eb8adda14a794d60469")
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# Find the audio features for a song.
temp_data = sp.audio_features(reduced_data['url'][0])[0]
temp_data
# Out:
# {'danceability': 0.852,
#  'energy': 0.773,
#  'key': 8,
#  'loudness': -2.921,
#  'mode': 0,
#  'speechiness': 0.0776,
#  'acousticness': 0.187,
#  'instrumentalness': 3.05e-05,
#  'liveness': 0.159,
#  'valence': 0.907,
#  'tempo': 102.034,
#  'type': 'audio_features',
#  'id': '6mICuAdrwEjh6Y6lroV2Kg',
#  'uri': 'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'track_href': 'https://api.spotify.com/v1/tracks/6mICuAdrwEjh6Y6lroV2Kg',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6mICuAdrwEjh6Y6lroV2Kg',
#  'duration_ms': 195840,
#  'time_signature': 4}

# %%
# Access a single feature.
temp_data['danceability']
# Out:
# 0.852

# %%
# Add columns to existing dataset with the audio features.
# Implementing a timer to check the time for adding new columns.
import time
tic = time.perf_counter()

for index, row in reduced_data.iterrows():
    current = sp.audio_features(row['url'])[0]
    reduced_data.at[index,'danceability'] = float(current['danceability'])
    reduced_data.at[index,'energy'] = current['energy']
    reduced_data.at[index,'key'] = current['key']
    reduced_data.at[index,'loudness'] = current['loudness']
    reduced_data.at[index,'mode'] = current['mode']
    reduced_data.at[index,'speechiness'] = current['speechiness']
    reduced_data.at[index,'acousticness'] = current['acousticness']
    reduced_data.at[index,'instrumentalness'] = current['instrumentalness']
    reduced_data.at[index,'liveness'] = current['liveness']
    reduced_data.at[index,'valence'] = current['valence']
    reduced_data.at[index,'tempo'] = current['tempo']
    reduced_data.at[index,'duration_ms'] = current['duration_ms']
    print(str(int(((index+1)/reduced_data.shape[0])*100)) + '% done - ' + str(index+1) + ' of ' + str(reduced_data.shape[0]) + ' songs iterated.', end='\r')
    
toc = time.perf_counter()
print(f"Added new rows from external links in {toc - tic:0.4f} seconds")
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'danceability'] = current['danceability']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'energy'] = current['energy']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'key'] = current['key']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'loudness'] = current['loudness']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'mode'] = current['mode']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'speechiness'] = current['speechiness']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'acousticness'] = current['acousticness']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'instrumentalness'] = current['instrumentalness']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'liveness'] = current['liveness']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'valence'] = current['valence']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'tempo'] = current['tempo']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18512\3174284796.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'duration_ms'] = current['duration_ms']
# Added new rows from external links in 98.8128 seconds

# %%
reduced_data
# Out:
#                            title  rank        date  \
# 0        Chantaje (feat. Maluma)     1  2017-01-01
# 1    Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2     Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                         Safari     4  2017-01-01
# 4                    Shaky Shaky     5  2017-01-01
# ..                           ...   ...         ...
# 995            Tim Tim - Ao Vivo   126  2017-01-01
# 996            Folgado - Ao Vivo   127  2017-01-01
# 997                   Photograph   128  2017-01-01
# 998                     Starving   129  2017-01-01
# 999      Scars To Your Beautiful   130  2017-01-01
#
#                                     artist  \
# 0                                  Shakira
# 1                             Ricky Martin
# 2                                     CNCO
# 3    J Balvin, Pharrell Williams, BIA, Sky
# 4                             Daddy Yankee
# ..                                     ...
# 995                         Wesley Safadão
# 996                       Marília Mendonça
# 997                             Ed Sheeran
# 998           Hailee Steinfeld, Grey, Zedd
# 999                           Alessia Cara
#
#                                                    url     region   chart  \
# 0    https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1    https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2    https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3    https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# 4    https://open.spotify.com/track/58IL315gMSTD37D...  Argentina  top200
# ..                                                 ...        ...     ...
# 995  https://open.spotify.com/track/4bftZ7IayYg0I6q...     Brazil  top200
# 996  https://open.spotify.com/track/4DYmJ19DhmxUe26...     Brazil  top200
# 997  https://open.spotify.com/track/6fxVffaTuwjgEk5...     Brazil  top200
# 998  https://open.spotify.com/track/1qOLh0tI7trd1zd...     Brazil  top200
# 999  https://open.spotify.com/track/0prNGof3XqfTvND...     Brazil  top200
#
#              trend   streams  danceability  ...   key  loudness  mode  \
# 0    SAME_POSITION  253019.0         0.852  ...   8.0    -2.921   0.0
# 1          MOVE_UP  223988.0         0.663  ...  11.0    -4.070   0.0
# 2        MOVE_DOWN  210943.0         0.761  ...   4.0    -3.073   0.0
# 3    SAME_POSITION  173865.0         0.508  ...   0.0    -4.361   1.0
# 4          MOVE_UP  153956.0         0.899  ...   6.0    -4.228   0.0
# ..             ...       ...           ...  ...   ...       ...   ...
# 995        MOVE_UP   37363.0         0.676  ...   2.0    -4.964   0.0
# 996        MOVE_UP   37320.0         0.712  ...   1.0    -3.792   0.0
# 997      MOVE_DOWN   37266.0         0.614  ...   4.0   -10.480   1.0
# 998      MOVE_DOWN   37178.0         0.636  ...   4.0    -4.230   1.0
# 999      MOVE_DOWN   37132.0         0.573  ...   0.0    -5.740   1.0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.0776       0.18700          0.000030    0.1590    0.907  102.034
# 1         0.2260       0.00431          0.000017    0.1010    0.533   99.935
# 2         0.0502       0.40000          0.000000    0.1760    0.710   93.974
# 3         0.3260       0.55100          0.000003    0.1260    0.555  180.044
# 4         0.2920       0.07600          0.000000    0.0631    0.873   88.007
# ..           ...           ...               ...       ...      ...      ...
# 995       0.0504       0.58100          0.000000    0.1430    0.891  163.998
# 996       0.0729       0.64500          0.000000    0.0726    0.569  163.848
# 997       0.0476       0.60700          0.000464    0.0986    0.201  107.989
# 998       0.1260       0.37100          0.000000    0.1020    0.512   99.721
# 999       0.1290       0.02850          0.000000    0.1110    0.451   97.085
#
#      duration_ms
# 0       195840.0
# 1       259196.0
# 2       222560.0
# 3       205600.0
# 4       234320.0
# ..           ...
# 995     174067.0
# 996     163902.0
# 997     258987.0
# 998     181880.0
# 999     230227.0
#
# [1000 rows x 21 columns]

# %%
reduced_data.shape
# Out:
# (1000, 21)

# %%
reduced_data.columns
# Out:
# Index(['title', 'rank', 'date', 'artist', 'url', 'region', 'chart', 'trend',
#        'streams', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms'],
#       dtype='object')

# %%
### Saving the sub dataset for testing.
from pathlib import Path  
path = Path('../../data/music-subset.csv')  
path.parent.mkdir(parents=True, exist_ok=True)  
reduced_data.to_csv(path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [30], in <module>
#       3 path = Path('../../data/music-subset.csv')
#       4 path.parent.mkdir(parents=True, exist_ok=True)
# ----> 5 reduced_data.to_csv(path, skiprows=1)
#
# TypeError: NDFrame.to_csv() got an unexpected keyword argument 'skiprows'

# %% [markdown]
# ***
# ### Adding lyrics to the list

# %%
from lyricsgenius import Genius

# Genius credentials
genius_token = "4SoLPv5UHyFZyAe5T-PhxS-bRCRrdNIgMNpeqjjIaWvnRbUmTpoGxd9knxBtlQyg"

genius = Genius(genius_token)
artist = genius.search_artist("Andy Shauf", max_songs=3, sort="title")
print(artist.songs)
# Out:
# Searching for songs by Andy Shauf...
#
# Song 1: "Alexander All Alone"
# Song 2: "All the Same"
# Song 3: "Angela"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# [Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...)]
