# %% [markdown]
# ## Preperation for data science examn project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
import sklearn.metrics as sm

# %%
data = pd.read_csv('../../data/cleanedDataset.csv')

# %%
data.shape
# Out:
# (104561, 8)

# %%
data.head()
# Out:
#    Unnamed: 0                               title  rank        date  \
# 0           0             Chantaje (feat. Maluma)     1  2017-01-01
# 1    10123748  Despacito (Featuring Daddy Yankee)     1  2017-04-07
# 2     1305825                               ภาพจำ     1  2018-04-12
# 3     2943946                     Te Boté - Remix     1  2018-04-27
# 4    19131998                            Binibini     1  2021-04-16
#
#                                               artist  \
# 0                                            Shakira
# 1                                         Luis Fonsi
# 2                                       Pop Pongkool
# 3  Nio Garcia, Casper Magico, Bad Bunny, Darell, ...
# 4                                       Zack Tabudlo
#
#                                                  url              region  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...           Argentina
# 1  https://open.spotify.com/track/4aWmUDTfIPGksMN...  Dominican Republic
# 2  https://open.spotify.com/track/4YRpjJaJpiI36HM...            Thailand
# 3  https://open.spotify.com/track/3V8UKqhEK5zBkBb...            Honduras
# 4  https://open.spotify.com/track/2X5AFygz5SDYlXa...         Philippines
#
#     streams
# 0  253019.0
# 1   11681.0
# 2   15477.0
# 3   12869.0
# 4  401678.0

# %%
data.tail()
# Out:
#         Unnamed: 0                title  rank        date          artist  \
# 104556     6064182  Coraz bliżej Święta   200  2018-11-23        Nosowska
# 104557     5844273            Ik Heb Je   200  2018-10-26            Maan
# 104558    19755890          המנון הלוחם   200  2021-04-23       Hatikva 6
# 104559     5938376       ครางชื่ออ้ายแน   200  2018-10-27  ศรีจันทร์ วีสี
# 104560      237825               好久不見的你   200  2017-02-05             施易男
#
#                                                       url       region  \
# 104556  https://open.spotify.com/track/2K6hdg6MKfKrDQB...       Poland
# 104557  https://open.spotify.com/track/2Xqs5ozueApOYZm...  Netherlands
# 104558  https://open.spotify.com/track/2i1xX8VmwMDtmF7...       Israel
# 104559  https://open.spotify.com/track/5ZwxJQ8vR5cHWer...     Thailand
# 104560  https://open.spotify.com/track/3YRYLUJBuB1epfI...       Taiwan
#
#         streams
# 104556   9718.0
# 104557  25204.0
# 104558   3822.0
# 104559   2390.0
# 104560   2005.0

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'title', 'rank', 'date', 'artist', 'url', 'region',
#        'streams'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# rank          0
# date          0
# artist        0
# url           0
# region        0
# streams       0
# dtype: int64

# %% [markdown]
# ***
# # Martins databehandling

# %%
# Set the amount of rows in sub set.
reduced_data = data.iloc[0:1000]

# %%
# Check the shape of the dataset.
reduced_data.shape
# Out:
# (1000, 8)

# %%
# Find link for accessing data for each song.
reduced_data['url'][0]
# Out:
# 'https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg'

# %%
reduced_data.head()
# Out:
#    Unnamed: 0                               title  rank        date  \
# 0           0             Chantaje (feat. Maluma)     1  2017-01-01
# 1    10123748  Despacito (Featuring Daddy Yankee)     1  2017-04-07
# 2     1305825                               ภาพจำ     1  2018-04-12
# 3     2943946                     Te Boté - Remix     1  2018-04-27
# 4    19131998                            Binibini     1  2021-04-16
#
#                                               artist  \
# 0                                            Shakira
# 1                                         Luis Fonsi
# 2                                       Pop Pongkool
# 3  Nio Garcia, Casper Magico, Bad Bunny, Darell, ...
# 4                                       Zack Tabudlo
#
#                                                  url              region  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...           Argentina
# 1  https://open.spotify.com/track/4aWmUDTfIPGksMN...  Dominican Republic
# 2  https://open.spotify.com/track/4YRpjJaJpiI36HM...            Thailand
# 3  https://open.spotify.com/track/3V8UKqhEK5zBkBb...            Honduras
# 4  https://open.spotify.com/track/2X5AFygz5SDYlXa...         Philippines
#
#     streams
# 0  253019.0
# 1   11681.0
# 2   15477.0
# 3   12869.0
# 4  401678.0

# %% [markdown]
# ### Import SpotiPY and insert ID and Secret to access audio features from spotify.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Authentication spotify - without user
client_credentials_manager = SpotifyClientCredentials(client_id="3a2f65eb20164b24b59b7fdd6876bb51", client_secret="9f6d3a070cdf4eb8adda14a794d60469")
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# Find the audio features for a song.
temp_data = sp.audio_features(reduced_data['url'][0])[0]
temp_data
# Out:
# {'danceability': 0.852,
#  'energy': 0.773,
#  'key': 8,
#  'loudness': -2.921,
#  'mode': 0,
#  'speechiness': 0.0776,
#  'acousticness': 0.187,
#  'instrumentalness': 3.05e-05,
#  'liveness': 0.159,
#  'valence': 0.907,
#  'tempo': 102.034,
#  'type': 'audio_features',
#  'id': '6mICuAdrwEjh6Y6lroV2Kg',
#  'uri': 'spotify:track:6mICuAdrwEjh6Y6lroV2Kg',
#  'track_href': 'https://api.spotify.com/v1/tracks/6mICuAdrwEjh6Y6lroV2Kg',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6mICuAdrwEjh6Y6lroV2Kg',
#  'duration_ms': 195840,
#  'time_signature': 4}

# %%
# Track url for 1st song in dataset.
reduced_data['url'][0]
# Out:
# 'https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg'

# %%
# Access a single feature.
temp_data['danceability']
# Out:
# 0.852

# %%
temp_data2 = sp.track(reduced_data['url'][0])
temp_data2
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#     'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#     'id': '0EmeFodog0BfCgMzAIvKQp',
#     'name': 'Shakira',
#     'type': 'artist',
#     'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6bUxh58rYTL67FS8dyTKMN'},
#   'href': 'https://api.spotify.com/v1/albums/6bUxh58rYTL67FS8dyTKMN',
#   'id': '6bUxh58rYTL67FS8dyTKMN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d05d3aad30c5fb7614893cf5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d05d3aad30c5fb7614893cf5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d05d3aad30c5fb7614893cf5',
#     'width': 64}],
#   'name': 'El Dorado',
#   'release_date': '2017-05-26',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:6bUxh58rYTL67FS8dyTKMN'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#    'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#    'id': '0EmeFodog0BfCgMzAIvKQp',
#    'name': 'Shakira',
#    'type': 'artist',
#    'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1r4hJ1h58CWwUQe3MxPuau'},
#    'href': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau',
#    'id': '1r4hJ1h58CWwUQe3MxPuau',
#    'name': 'Maluma',
#    'type': 'artist',
#    'uri': 'spotify:artist:1r4hJ1h58CWwUQe3MxPuau'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 195840,
#  'explicit': False,
#  'external_ids': {'isrc': 'USSD11600299'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6mICuAdrwEjh6Y6lroV2Kg'},
#  'href': 'https://api.spotify.com/v1/tracks/6mICuAdrwEjh6Y6lroV2Kg',
#  'id': '6mICuAdrwEjh6Y6lroV2Kg',
#  'is_local': False,
#  'name': 'Chantaje (feat. Maluma)',
#  'popularity': 74,
#  'preview_url': 'https://p.scdn.co/mp3-preview/b7a66b261ebbe2aa79f2ce9b4dd540cd1fc2fb78?cid=3a2f65eb20164b24b59b7fdd6876bb51',
#  'track_number': 3,
#  'type': 'track',
#  'uri': 'spotify:track:6mICuAdrwEjh6Y6lroV2Kg'}

# %%
# Image url
image_url = temp_data2['album']['images'][0]['url']
image_url
# Out:
# 'https://i.scdn.co/image/ab67616d0000b273d05d3aad30c5fb7614893cf5'

# %%
# Add columns to existing dataset with the audio features.
# Implementing a timer to check the time for adding new columns.
import time
tic = time.perf_counter()

for index, row in reduced_data.iterrows():
    current = sp.audio_features(row['url'])[0]
    reduced_data.at[index,'danceability'] = float(current['danceability'])
    reduced_data.at[index,'energy'] = current['energy']
    reduced_data.at[index,'key'] = current['key']
    reduced_data.at[index,'loudness'] = current['loudness']
    reduced_data.at[index,'mode'] = current['mode']
    reduced_data.at[index,'speechiness'] = current['speechiness']
    reduced_data.at[index,'acousticness'] = current['acousticness']
    reduced_data.at[index,'instrumentalness'] = current['instrumentalness']
    reduced_data.at[index,'liveness'] = current['liveness']
    reduced_data.at[index,'valence'] = current['valence']
    reduced_data.at[index,'tempo'] = current['tempo']
    reduced_data.at[index,'duration_ms'] = current['duration_ms']
    print(str(int(((index+1)/reduced_data.shape[0])*100)) + '% done - ' + str(index+1) + ' of ' + str(reduced_data.shape[0]) + ' songs iterated.', end='\r')
    
toc = time.perf_counter()
print(f"Added new rows from external links in {toc - tic:0.4f} seconds")
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'danceability'] = float(current['danceability'])
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'energy'] = current['energy']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'key'] = current['key']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'loudness'] = current['loudness']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'mode'] = current['mode']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'speechiness'] = current['speechiness']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'acousticness'] = current['acousticness']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'instrumentalness'] = current['instrumentalness']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'liveness'] = current['liveness']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'valence'] = current['valence']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'tempo'] = current['tempo']
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\3303427338.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.at[index,'duration_ms'] = current['duration_ms']
# Added new rows from external links in 98.4555 seconds

# %%
reduced_data.drop( columns={'Unnamed: 0':'index'}, inplace=True, axis=1 )
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_18124\2979073468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_data.drop( columns={'Unnamed: 0':'index'}, inplace=True, axis=1 )

# %%
reduced_data.reset_index()
# Out:
#      index                               title  rank        date  \
# 0        0             Chantaje (feat. Maluma)     1  2017-01-01
# 1        1  Despacito (Featuring Daddy Yankee)     1  2017-04-07
# 2        2                               ภาพจำ     1  2018-04-12
# 3        3                     Te Boté - Remix     1  2018-04-27
# 4        4                            Binibini     1  2021-04-16
# ..     ...                                 ...   ...         ...
# 995    995         PUSSY (feat. Lazza & Salmo)     1  2020-05-10
# 996    996                           Karantene     1  2020-04-17
# 997    997                       Gác Lại Âu Lo     1  2020-08-01
# 998    998                            Medicina     1  2018-08-17
# 999    999                            Trapwave     1  2020-05-10
#
#                                                 artist  \
# 0                                              Shakira
# 1                                           Luis Fonsi
# 2                                         Pop Pongkool
# 3    Nio Garcia, Casper Magico, Bad Bunny, Darell, ...
# 4                                         Zack Tabudlo
# ..                                                 ...
# 995                                     Dark Polo Gang
# 996                                                TIX
# 997                                     Da LAB, Miu Lê
# 998                                             Anitta
# 999                                        Young Wavee
#
#                                                    url              region  \
# 0    https://open.spotify.com/track/6mICuAdrwEjh6Y6...           Argentina
# 1    https://open.spotify.com/track/4aWmUDTfIPGksMN...  Dominican Republic
# 2    https://open.spotify.com/track/4YRpjJaJpiI36HM...            Thailand
# 3    https://open.spotify.com/track/3V8UKqhEK5zBkBb...            Honduras
# 4    https://open.spotify.com/track/2X5AFygz5SDYlXa...         Philippines
# ..                                                 ...                 ...
# 995  https://open.spotify.com/track/7MhzmWFJYSEsL8w...               Italy
# 996  https://open.spotify.com/track/6sMMfGxa9tB59dM...              Norway
# 997  https://open.spotify.com/track/6HpDKKSDZ8QpSHf...             Vietnam
# 998  https://open.spotify.com/track/4R5xvs5X0phd0EY...              Brazil
# 999  https://open.spotify.com/track/1v3Z3GQRvXvRILy...              Israel
#
#       streams  danceability  energy   key  loudness  mode  speechiness  \
# 0    253019.0         0.852   0.773   8.0    -2.921   0.0       0.0776
# 1     11681.0         0.660   0.786   2.0    -4.757   1.0       0.1700
# 2     15477.0         0.557   0.585   5.0    -7.559   0.0       0.0470
# 3     12869.0         0.903   0.675  11.0    -3.445   0.0       0.2140
# 4    401678.0         0.642   0.374   5.0   -10.606   1.0       0.0320
# ..        ...           ...     ...   ...       ...   ...          ...
# 995  334344.0         0.852   0.751   9.0    -3.738   1.0       0.2800
# 996  124824.0         0.628   0.754   0.0    -7.497   1.0       0.0348
# 997   27084.0         0.745   0.527   6.0    -8.090   1.0       0.0786
# 998  489983.0         0.798   0.784   4.0    -3.545   0.0       0.0667
# 999   21478.0         0.918   0.570  10.0    -7.830   1.0       0.2460
#
#      acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.1870          0.000030    0.1590   0.9070  102.034     195840.0
# 1          0.2090          0.000000    0.1120   0.8460  177.833     228200.0
# 2          0.4260          0.000001    0.1440   0.4640   81.922     274000.0
# 3          0.5420          0.000013    0.0595   0.4420   96.507     417920.0
# 4          0.4230          0.000002    0.4350   0.0979  129.863     221538.0
# ..            ...               ...       ...      ...      ...          ...
# 995        0.2520          0.000010    0.1660   0.7000  150.010     161325.0
# 996        0.2430          0.000000    0.3740   0.6470  104.989     132514.0
# 997        0.5710          0.000000    0.1100   0.3850   95.034     282629.0
# 998        0.0441          0.012900    0.1490   0.6530   93.960     141508.0
# 999        0.2390          0.000000    0.0838   0.7570  120.039     138953.0
#
# [1000 rows x 20 columns]

# %%
reduced_data.head()
# Out:
#                                 title  rank        date  \
# 0             Chantaje (feat. Maluma)     1  2017-01-01
# 1  Despacito (Featuring Daddy Yankee)     1  2017-04-07
# 2                               ภาพจำ     1  2018-04-12
# 3                     Te Boté - Remix     1  2018-04-27
# 4                            Binibini     1  2021-04-16
#
#                                               artist  \
# 0                                            Shakira
# 1                                         Luis Fonsi
# 2                                       Pop Pongkool
# 3  Nio Garcia, Casper Magico, Bad Bunny, Darell, ...
# 4                                       Zack Tabudlo
#
#                                                  url              region  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...           Argentina
# 1  https://open.spotify.com/track/4aWmUDTfIPGksMN...  Dominican Republic
# 2  https://open.spotify.com/track/4YRpjJaJpiI36HM...            Thailand
# 3  https://open.spotify.com/track/3V8UKqhEK5zBkBb...            Honduras
# 4  https://open.spotify.com/track/2X5AFygz5SDYlXa...         Philippines
#
#     streams  danceability  energy   key  loudness  mode  speechiness  \
# 0  253019.0         0.852   0.773   8.0    -2.921   0.0       0.0776
# 1   11681.0         0.660   0.786   2.0    -4.757   1.0       0.1700
# 2   15477.0         0.557   0.585   5.0    -7.559   0.0       0.0470
# 3   12869.0         0.903   0.675  11.0    -3.445   0.0       0.2140
# 4  401678.0         0.642   0.374   5.0   -10.606   1.0       0.0320
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# 0         0.187          0.000030    0.1590   0.9070  102.034     195840.0
# 1         0.209          0.000000    0.1120   0.8460  177.833     228200.0
# 2         0.426          0.000001    0.1440   0.4640   81.922     274000.0
# 3         0.542          0.000013    0.0595   0.4420   96.507     417920.0
# 4         0.423          0.000002    0.4350   0.0979  129.863     221538.0

# %%
reduced_data.columns
# Out:
# Index(['title', 'rank', 'date', 'artist', 'url', 'region', 'streams',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
### Saving the sub dataset for testing.
from pathlib import Path  
path = Path('../../data/music-subset.csv')  
path.parent.mkdir(parents=True, exist_ok=True)  
reduced_data.to_csv(path)

# %% [markdown]
# ***
# ### Adding lyrics to the list

# %%
from lyricsgenius import Genius

# Genius credentials
genius_token = "4SoLPv5UHyFZyAe5T-PhxS-bRCRrdNIgMNpeqjjIaWvnRbUmTpoGxd9knxBtlQyg"

genius = Genius(genius_token)
artist = genius.search_artist("Andy Shauf", max_songs=3, sort="title")
print(artist.songs)
# Out:
# Searching for songs by Andy Shauf...
#
# Song 1: "Alexander All Alone"
# Song 2: "All the Same"
# Song 3: "Angela"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# [Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...)]

# %%
import re
import tokenize
sentence = "Hejsa hvordan går det med dig, ok det lyder godt"

def word_extraction(sentence):    
    ignore = ['a', "the", "is"]    
    words = re.sub("[^\w]", " ",  sentence).split()    
    cleaned_text = [
        w.lower() for w in words if w not in ignore
    ]    
    return cleaned_text

# %%
def create_word_dictionary(lyric):
    words=lyric.split(" ")
    word_dictionary = {}
    for word in words:
        if word in word_dictionary:
            word_dictionary[word] = word_dictionary[word]+1
        else:
            word_dictionary[word]=1
    return word_dictionary

# %%
create_word_dictionary("aa a aa aaaa aa bb bbb b bbb bb bbb bbb cc ccc cccc cc ccc")
# Out:
# {'aa': 3,
#  'a': 1,
#  'aaaa': 1,
#  'bb': 2,
#  'bbb': 4,
#  'b': 1,
#  'cc': 2,
#  'ccc': 2,
#  'cccc': 1}
