# %% [markdown]
# # <center style="color: blue" >Part 1 - Preparing the dataset (Cleaned Version)</center>

# %% [markdown]
# ***
# ## <center style="color: blue" >Imports needed for data exploration </center>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***
# ## <center style="color: blue" >Import the data set</center>

# %%
music_df = pd.read_csv('../data/charts.csv')

# %% [markdown]
# ***
# ## <center style="color: blue" >Explore the data set</center>

# %%
music_df.head()
# Out:
#                          title  rank        date  \
# 0      Chantaje (feat. Maluma)     1  2017-01-01
# 1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                       Safari     4  2017-01-01
# 4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  Argentina  top200
#
#            trend   streams
# 0  SAME_POSITION  253019.0
# 1        MOVE_UP  223988.0
# 2      MOVE_DOWN  210943.0
# 3  SAME_POSITION  173865.0
# 4        MOVE_UP  153956.0

# %%
music_df.tail()
# Out:
#                                   title  rank        date  \
# 26173509                            BYE    46  2021-07-31
# 26173510                        Pillars    47  2021-07-31
# 26173511                   Gái Độc Thân    48  2021-07-31
# 26173512  Renegade (feat. Taylor Swift)    49  2021-07-31
# 26173513                Letter to Jarad    50  2021-07-31
#
#                              artist  \
# 26173509                      Jaden
# 26173510                     My Anh
# 26173511                      Tlinh
# 26173512            Big Red Machine
# 26173513  LRN Slime, Shiloh Dynasty
#
#                                                         url   region    chart  \
# 26173509  https://open.spotify.com/track/3OUyyDN7EZrL7i0...  Vietnam  viral50
# 26173510  https://open.spotify.com/track/6eky30oFiQbHUAT...  Vietnam  viral50
# 26173511  https://open.spotify.com/track/2klsSb2iTfgDh95...  Vietnam  viral50
# 26173512  https://open.spotify.com/track/1aU1wpYBSpP0M6I...  Vietnam  viral50
# 26173513  https://open.spotify.com/track/508QhA2SncMbh5C...  Vietnam  viral50
#
#               trend  streams
# 26173509    MOVE_UP      NaN
# 26173510  NEW_ENTRY      NaN
# 26173511  MOVE_DOWN      NaN
# 26173512  MOVE_DOWN      NaN
# 26173513  MOVE_DOWN      NaN

# %%
music_df.shape
# Out:
# (26173514, 9)

# %%
music_df.dtypes
# Out:
# title       object
# rank         int64
# date        object
# artist      object
# url         object
# region      object
# chart       object
# trend       object
# streams    float64
# dtype: object

# %%
music_df.columns
# Out:
# Index(['title', 'rank', 'date', 'artist', 'url', 'region', 'chart', 'trend',
#        'streams'],
#       dtype='object')

# %%
music_df.isnull().sum()
# Out:
# title           11
# rank             0
# date             0
# artist          18
# url              0
# region           0
# chart            0
# trend            0
# streams    5851610
# dtype: int64

# %% [markdown]
# ## <center style="color: blue" >Remove unwanted rows and columns.</center>

# %% [markdown]
# ### Drop rows where title or artist is null.
#
# <span style="color: red">OBS -  We don't want to drop rows with null in streams, since it doesn't mean that there is missing values - just missing listeners.</span>

# %%
music_df = music_df.dropna(subset=['title', 'artist'])

# %%
# Check that values have been properly removed.
music_df.isnull().sum()
# Out:
# title            0
# rank             0
# date             0
# artist           0
# url              0
# region           0
# chart            0
# trend            0
# streams    5851588
# dtype: int64

# %% [markdown]
# ### Drop rows with duplicates in both title and artist.
#
# Since we only want to make predictions on wheither a song can hit a top list or not, we don't need duplicates of the same song from different weeks.
#
# (A song appearing on a list for more than one week.)

# %%
music_df = music_df.drop_duplicates(subset=['title', 'artist'], keep="first")
music_df
# Out:
#                                                title  rank        date  \
# 0                            Chantaje (feat. Maluma)     1  2017-01-01
# 1                        Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2                         Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                                             Safari     4  2017-01-01
# 4                                        Shaky Shaky     5  2017-01-01
# ...                                              ...   ...         ...
# 26160571                           Imparfait inconnu    28  2021-07-28
# 26162386  Still Holy (feat. Ryan Ofei & Naomi Raine)    47  2021-07-28
# 26165777                                          怎叹    48  2021-07-29
# 26168170                                    ילד השדה    45  2021-07-30
# 26171619                                     Believe    50  2021-07-31
#
#                                          artist  \
# 0                                       Shakira
# 1                                  Ricky Martin
# 2                                          CNCO
# 3         J Balvin, Pharrell Williams, BIA, Sky
# 4                                  Daddy Yankee
# ...                                         ...
# 26160571                                    Adé
# 26162386             Tribl, Maverick City Music
# 26165777                                     郑鱼
# 26168170                           Yehuda Elias
# 26171619                      Anna of the North
#
#                                                         url        region  \
# 0         https://open.spotify.com/track/6mICuAdrwEjh6Y6...     Argentina
# 1         https://open.spotify.com/track/7DM4BPaS7uofFul...     Argentina
# 2         https://open.spotify.com/track/3AEZUABDXNtecAO...     Argentina
# 3         https://open.spotify.com/track/6rQSrBHf7HlZjtc...     Argentina
# 4         https://open.spotify.com/track/58IL315gMSTD37D...     Argentina
# ...                                                     ...           ...
# 26160571  https://open.spotify.com/track/3W7x967esdawMwz...        France
# 26162386  https://open.spotify.com/track/4Cw36mfQ1z4JnjF...  South Africa
# 26165777  https://open.spotify.com/track/02jBlxoKmrSXrHE...     Singapore
# 26168170  https://open.spotify.com/track/4JaLSvGiHdm4RK8...        Israel
# 26171619  https://open.spotify.com/track/5U8frcz1zLfKDX5...       Ireland
#
#             chart          trend   streams
# 0          top200  SAME_POSITION  253019.0
# 1          top200        MOVE_UP  223988.0
# 2          top200      MOVE_DOWN  210943.0
# 3          top200  SAME_POSITION  173865.0
# 4          top200        MOVE_UP  153956.0
# ...           ...            ...       ...
# 26160571  viral50      NEW_ENTRY       NaN
# 26162386  viral50      NEW_ENTRY       NaN
# 26165777  viral50      NEW_ENTRY       NaN
# 26168170  viral50      NEW_ENTRY       NaN
# 26171619  viral50      NEW_ENTRY       NaN
#
# [197533 rows x 9 columns]

# %% [markdown]
# ### Drop columns that we can't use for predictions.

# %%
# Finding unique types in chart
music_df.chart.unique()
# Out:
# array(['top200', 'viral50'], dtype=object)

# %% [markdown]
# **There are two different values in "Chart" - 'top200' and 'viral50'.**
#
# In this project we are interested in inspecting and operating on data for the top chart of spotify.
#
# This is in our opinion the 'top200'-list, as the 'viral50'-list is a list determinated by Social media.
#
# The more talk and chatting on a specific track, determine the probability of ending up on the 'viral50'-list.
#
# This is the reason we  remove this from the dataset.

# %%
music_df = music_df[music_df.chart.str.contains("viral50") == False]

# %%
music_df
# Out:
#                                 title  rank        date  \
# 0             Chantaje (feat. Maluma)     1  2017-01-01
# 1         Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2          Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                              Safari     4  2017-01-01
# 4                         Shaky Shaky     5  2017-01-01
# ...                               ...   ...         ...
# 24917263                       คิดมาก   157  2017-12-31
# 24917289    โต้รุ่ง (feat. โจอี้ บอย)   183  2017-12-31
# 25088276                  Na Szczycie   182  2018-01-29
# 25096450                    All Right   175  2018-01-29
# 25102623               All Falls Down    79  2018-01-30
#
#                                                      artist  \
# 0                                                   Shakira
# 1                                              Ricky Martin
# 2                                                      CNCO
# 3                     J Balvin, Pharrell Williams, BIA, Sky
# 4                                              Daddy Yankee
# ...                                                     ...
# 24917263                                              Palmy
# 24917289                           Boom Boom Cash, Joey Boy
# 25088276                                            Grubson
# 25096450                                         Red Velvet
# 25102623  Alan Walker, Noah Cyrus, Digital Farm Animals,...
#
#                                                         url     region  \
# 0         https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina
# 1         https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina
# 2         https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina
# 3         https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina
# 4         https://open.spotify.com/track/58IL315gMSTD37D...  Argentina
# ...                                                     ...        ...
# 24917263  https://open.spotify.com/track/7fil1CerP6aA0hU...   Thailand
# 24917289  https://open.spotify.com/track/3QSftcwKhotprns...   Thailand
# 25088276  https://open.spotify.com/track/7aQViYYpIkpJwyC...     Poland
# 25096450  https://open.spotify.com/track/2SahFuW1EZN9MXN...   Thailand
# 25102623  https://open.spotify.com/track/0UBLhedidy1DjSF...    Austria
#
#            chart          trend   streams
# 0         top200  SAME_POSITION  253019.0
# 1         top200        MOVE_UP  223988.0
# 2         top200      MOVE_DOWN  210943.0
# 3         top200  SAME_POSITION  173865.0
# 4         top200        MOVE_UP  153956.0
# ...          ...            ...       ...
# 24917263  top200      NEW_ENTRY    1445.0
# 24917289  top200      NEW_ENTRY    1285.0
# 25088276  top200      NEW_ENTRY    7386.0
# 25096450  top200      NEW_ENTRY    1488.0
# 25102623  top200        MOVE_UP    4018.0
#
# [100220 rows x 9 columns]

# %% [markdown]
# **The dataset has a trend column. This is the movement of a song on the chart, whether it has moved up or down the chart. We know that this dataset is collected weekley, and therefore there are dublicates of the songs on different positions. We are not interested in the same song multiple times, so we will try to remove these dublicates so we can get a much cleaner dataset.**
#
#
# **The trend colum is in our oppinion not nessesary for analysing the dataset, while we do not make any measurements on the movement of the individual tracks. This is the reason why we remove it.**
#
# **And the column chart only holds a single value 'top200', so now we can remove this one aswell.**

# %%
music_df = music_df.drop(['trend', 'chart'], axis=1)

# %%
# Check what columns we have left.
list(music_df)
# Out:
# ['title', 'rank', 'date', 'artist', 'url', 'region', 'streams']

# %%
# Check the shape
music_df.shape
# Out:
# (100220, 7)

# %% [markdown]
# ***
# ## <center style="color: blue" >Convert data values</center>

# %%
# Convert streams column to integer values - and convert NaN values to 0.
music_df['streams'] = np.nan_to_num(music_df['streams']).astype(int)

# %%
# Check that values have been converted properly.
music_df.head()
# Out:
#                          title  rank        date  \
# 0      Chantaje (feat. Maluma)     1  2017-01-01
# 1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                       Safari     4  2017-01-01
# 4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region  streams
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina   253019
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina   223988
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina   210943
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina   173865
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  Argentina   153956

# %%
music_df.dtypes
# Out:
# title      object
# rank        int64
# date       object
# artist     object
# url        object
# region     object
# streams     int32
# dtype: object

# %% [markdown]
# ***
# ## <center style="color: blue" >Reset index after cleaning the dataset.</center>

# %%
# Sort the values based on the column 'rank'.
music_df = music_df.sort_values('rank', ascending=True)

# %%
# Reset the index files, so every entry has their own id.
music_df.reset_index(drop=True, inplace=True)

# %%
music_df
# Out:
#                                title  rank        date  \
# 0            Chantaje (feat. Maluma)     1  2017-01-01
# 1                           Waterval     1  2021-11-28
# 2         Kafamda kentsel dönüşümler     1  2020-08-01
# 3                      POLSKIE TANGO     1  2020-08-01
# 4              Bir İhtimal Biliyorum     1  2019-01-01
# ...                              ...   ...         ...
# 100215  Tuổi Gì Mà Chẳng Thích Lì Xì   200  2020-01-20
# 100216                   El Problema   200  2020-05-01
# 100217                      未見過世面的招積   200  2021-10-19
# 100218                    Beamer Boi   200  2020-05-02
# 100219                       Noticed   200  2020-06-01
#
#                            artist  \
# 0                         Shakira
# 1                              K3
# 2                   İkiye On Kala
# 3           Taco Hemingway, Lanek
# 4                          Gülşen
# ...                           ...
# 100215     Bich Phuong, Bình Gold
# 100216             Ricardo Arjona
# 100217                    Kay Tse
# 100218  Khontkar, Myndless Grimes
# 100219                  Lil Mosey
#
#                                                       url     region  streams
# 0       https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina   253019
# 1       https://open.spotify.com/track/6Y3VGa2XlHkuJnS...    Belgium    73917
# 2       https://open.spotify.com/track/7iEfRnNqAcTse7A...     Turkey   140603
# 3       https://open.spotify.com/track/2fNLY6Ks5tKg2e4...     Poland   157811
# 4       https://open.spotify.com/track/24mpJgP2YZUBif9...     Turkey   108528
# ...                                                   ...        ...      ...
# 100215  https://open.spotify.com/track/6tOyEmIo6e3VzO9...    Vietnam     2321
# 100216  https://open.spotify.com/track/5UJsYyBi0CdSJl0...  Guatemala     3445
# 100217  https://open.spotify.com/track/6Eh74dmYzQtnMUy...  Hong Kong     3232
# 100218  https://open.spotify.com/track/7zzI3SbctTJN6wD...     Turkey    21700
# 100219  https://open.spotify.com/track/7zLYKWcXnYeHHWi...     Canada    28402
#
# [100220 rows x 7 columns]

# %% [markdown]
# ***
# ## <center style="color: blue" >Save the cleaned dataset</center>

# %%
#Saving found data to csv file
from pathlib import Path  
path = Path('../data/Data sets (Martins stages)/Stage 1 - Cleaned dataset.csv')  
path.parent.mkdir(parents=True, exist_ok=True)  
music_df.to_csv(path)
